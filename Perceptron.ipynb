# %%
import random
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
a = random.randint(-10,11)
b = random.randint(-10,11)
x1 = [0]*20
x2 = [0]*20
y = [-1]*20
w = [1]*3
incorrect = []
print("Target function x2 = ",a,"x1 -",b)
for i in range(20):
    x1[i] = random.randint(-50,51)
    x2[i] = random.randint(-50,51)
    print((x1[i],x2[i]))
    if(x2[i]-a*x1[i]-b>=0):
        y[i]=1
# Out:
# Target function x2 =  9 x1 - 4
# (-34, -22)
# (-16, -43)
# (-16, 27)
# (38, 19)
# (-28, -42)
# (11, -32)
# (-24, -20)
# (-8, 49)
# (-15, -46)
# (45, -34)
# (-31, 20)
# (-11, 44)
# (-42, 48)
# (35, 51)
# (-32, -3)
# (-2, -30)
# (-8, 36)
# (39, 7)
# (41, 3)
# (39, 29)

# %%
fig = plt.figure()
ax = plt.axes()
plt.xlim(-50, 50)
plt.ylim(-50, 50)
x = np.linspace(-50, 50, 1000)
plt.plot(x,a*x+b)
for i in range(20):
    if(y[i]==1):
        plt.plot(x1[i],x2[i],'o',color='blue')
    else:
        plt.plot(x1[i],x2[i],'o',color='red')
plt.plot(x,-w[1]/w[2]*x-w[0]/w[2])

# %%
def evaluate(x1,x2,w,y,incorrect):
    incorrect = []
    for i in range(20):
        output = np.sign(w[0]+w[1]*x1[i]+w[2]*x2[i]);
        if(y[i]!=output):
            incorrect.append(i)
    return incorrect

# %%
incorrect = evaluate(x1,x2,w,y,incorrect)
count = 0
plt.xlim(-50, 50)
plt.ylim(-50, 50)
while(len(incorrect)>0):
    index = random.choice(incorrect)
    w[0] = w[0] + y[index]
    w[1] = w[1] + y[index]*x1[index]
    w[2] = w[2] + y[index]*x2[index]
    incorrect = evaluate(x1,x2,w,y,incorrect)
    count=count+1
    print("After ",count, "iterations")
    if(w[2]!=0):
        plt.plot(x,-w[1]/w[2]*x-w[0]/w[2])
# Out:
# After  1 iterations
# After  2 iterations
# After  3 iterations
# After  4 iterations
# After  5 iterations

# %%
print("Final w:",w)
print("Final hypothesis: x2 = ",-w[1]/w[2],"x1 -",w[0]/w[2])
plt.xlim(-50, 50)
plt.ylim(-50, 50)
plt.plot(x,a*x+b)
for i in range(20):
    if(y[i]==1):
        plt.plot(x1[i],x2[i],'o',color='blue')
    else:
        plt.plot(x1[i],x2[i],'o',color='red')
plt.plot(x,-w[1]/w[2]*x-w[0]/w[2])
# Out:
# Final w: [2, -47, 12]
# Final hypothesis: x2 =  3.9166666666666665 x1 - 0.16666666666666666
